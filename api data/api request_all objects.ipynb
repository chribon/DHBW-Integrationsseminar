# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
url_meta = "http://10.50.12.131:8081/meta/"
headers_meta = {
  'Authorization': 'Basic UmVzdHVzZXI6S2VubndvcnQwNA==',
  'Cookie': 'JSESSIONID=AAC2EFBE19BC028C7CE932443375F13B'
}
response_meta = requests.request("GET", url_meta, headers=headers_meta)
response_json_meta = json.loads(response_meta.text)
# print(response_json_meta)

# %%
# get a list of objects with list-option: (gibt auch einige, die diese Option nicht haben)
objects = []
for entry in response_json_meta:
    split = entry.split('.')
    if(split[1] == 'list'):
        objects.append(split[0])
# remove duplicates:
objects = list(dict.fromkeys(objects))
# print(objects)
# print(len(objects))

# %%
counter = 0

headers_data = {
      'Authorization': 'Basic UmVzdHVzZXI6S2VubndvcnQwNA==',
      'Cookie': 'JSESSIONID=AAC2EFBE19BC028C7CE932443375F13B'
    }
for obj in objects:
    # send request, get response
    url_data = "http://10.50.12.131:8081/data/" + str(obj) + "/list"
    response_data = requests.request("GET", url_data, headers=headers_data)
    response_json_data = json.loads(response_data.text)
    
    if(response_json_data):
        # get metainfos
        metainfos = response_json_data[0]
        datatype = metainfos['__type']

        if(datatype != 'ERROR'):
            metadata = metainfos['data']
            metadatalist = []
            for col in metadata:
                metadatalist.append(col['name'])

            # new DataFrame, save response content to df and save df content to csv
            df = pd.DataFrame(columns=metadatalist)
            for key, row in enumerate(response_json_data):
                if row['__rowType'] == 'DATA':
                    df.loc[key] = row['data']
            df.to_csv("apidata/" + str(obj) + "_" + str(datatype) + ".csv", sep=';', header=True, index=False)

            counter+=1
            print(str(obj) + ": " + str(counter))
        else: print(obj + ': ERROR')
    else: print(obj + ': leer')

print("Fertig!")
# Out:
# ATPInspectionGroup: ERROR
# ATPInspectionGroupAssignment: ERROR
# ATPWithdrawalBuffer: ERROR
# AbsenceReasons: 1
# AbsenceSettings: 2
# AbsenceToOrderBooking: leer
# AccessAlarmSuppression: leer
# AccessAlarmsAndDisturbancesHistory: leer
# AccessAuthorizations: leer
# AccessAuthorizationsHistory: ERROR
# AccessAuthorizationsList: ERROR
# AccessAuthorizationsTerminal: ERROR
# AccessGroups: leer
# AccessLog: ERROR
# AccessOpeningHours: leer
# AccessPoints: leer
# AccessProfileAssignment: ERROR
# AccessProfiles: leer
# AccessPublicHolidays: 3
# AccessStatus: leer
# AccessTimeModels: 4
# AccessTimeSpans: 5
# AccountingPeriods: 6
# AccountingPeriodsSelection: 7
# ActivityCodes: 8
# AnalysisAssignedComplaintAnalysis: 9
# AnalysisProcessParameter: ERROR
# AnalysisSelection: leer
# AnalysisTag: ERROR
# AnalysisWorkplace: ERROR
# AnalysisWorkplaceStatus: ERROR
# ArchiveDataManagement: 10
# ArchiveDataManagementObject: 11
# ArchiveReloadManager: ERROR
# Article: 12
# ArticleGroup: 13
# Assessment: ERROR
# AssessmentCatalog: 14
# AssessmentClass: 15
# AssessmentClassification: 16
# AssessmentCriterion: 17
# AssessmentSubject: ERROR
# AssignmentOfPremiumAreas: leer
# AssignmentOfPremiumGroups: leer
# AttendanceBonus: leer
# AuthorizationCockpit: ERROR
# BOBatch: leer
# BOOperation: 18
# BOOrder: 19
# BOPComponents: leer
# BOPCycleParameters: leer
# BOPDocLinks: ERROR
# BOPMaintenance: 20
# BOPNotes: ERROR
# BOPOrderSequences: leer
# BOPProductionResources: leer
# BOPerson: 21
# BOResource: 22
# BadgeLayout: 23
# Badges: 24
# BagCheck: leer
# BaselinePlan: leer
# BatchAttribute: leer
# BatchAttributeConfiguration: leer
# BatchLog: leer
# BatchRelation: leer
# BonusReasons: leer
# BradfordFactor: ERROR
# Category: leer
# ChangeOfPremiumGroups: leer
# CharacteristicAssignedComplaintAnalysis: 25
# CharacteristicStatistics: ERROR
# ClockingArchive: ERROR
# ClockingAuthorizations: 26
# Clockings: leer
# Company: 27
# ComparisonClockingsBookings: leer
# Complaint: 28
# ComplaintAnalysis: 29
# ComplaintAssignment: leer
# ComplaintCostAnalysis: 30
# ComplaintCosts: 31
# ComplaintDetail: 32
# ComplaintMeasures: 33
# ControlChart: ERROR
# ControlPlan: 34
# CostCenters: 35
# CostType: 36
# CostTypeGroup: 37
# CounterResourceToMachineAssignment: leer
# CustomService: ERROR
# DCAdeLogRecord: ERROR
# DNCFamilyToMachineAssignment: 38
# DNCVersions: ERROR
# DailyPersonalPerformance: ERROR
# DialogButton: 39
# DialogConfiguration: 40
# DialogField: 41
# DialogSystemProtocol: leer
# DialogWorkflow: 42
# DocumentAssignedComplaintAnalysis: ERROR
# DocumentComplaint: 43
# DocumentInspection: leer
# DocumentLink: ERROR
# DocumentLinkType: ERROR
# DynamicHistoryBatchRelated: leer
# DynamicHistoryCharacteristicRelated: leer
# DynamicModificationAQL: 44
# DynamicModificationLevel: 45
# DynamicModificationMethod: 46
# DynamicModificationStandard: 47
# EnergyRequirementsPlan: ERROR
# EnergyTargetActualComparison: ERROR
# EscalationEvaluation: leer
# EscalationEventConfiguration: ERROR
# EscalationEventRegistration: 48
# EscalationEventRegistrySolutions: 49
# EscalationEventRegistryVariables: 50
# EscalationFunctionGroups: leer
# EscalationMessages: leer
# EvaluationAssessmentCriterion: ERROR
# EvaluationAssessmentCriterionAnalysis: ERROR
# EvaluationsAssessmentManagement: ERROR
# EventMaintenance: ERROR
# Events: leer
# ExternalPerson: 51
# ExternalReport: 52
# FMEAEvaluationNumber: ERROR
# FMEAEvaluationNumberEntry: ERROR
# FMEAStructureNet: ERROR
# FMEAStructureTree: ERROR
# Failure: 53
# FailureGroup: 54
# FailureModeAnalysis: 55
# FailureModeAnalysisComplaint: 56
# FailureModeEffectsAnalysisOverview: ERROR
# FormansChecklist: 57
# Gage: 58
# GraphicMachinery: 59
# GraphicMachineryObject: 60
# GroupBonusRecords: ERROR
# GroupPerformanceDevelopment: ERROR
# Histogram: leer
# IncentiveBonuses: leer
# IncentiveWageBasicSettings: 61
# IncentiveWageCalculation: 62
# IncentiveWageInterfaceToPayrollAccounting: ERROR
# IniConfiguration: 63
# IniDataConfiguration: 64
# InspectionCharacteristic: ERROR
# InspectionPlan: 65
# InspectionPlanCharacteristic: 66
# InspectionPlanReference: 67
# InspectionPoint: leer
# InspectionRequirement: ERROR
# InspectionSample: leer
# InspectionSeverity: 68
# InspectionSeverityEntry: 69
# InspectionStations: 70
# InspectionStep: 71
# InterpolationPoint: ERROR
# InventoryLevelProjection: ERROR
# InventoryLimit: leer
# JobTrigger: ERROR
# Kanban: leer
# LabelAssignment: leer
# LabelDesign: leer
# LabelReprint: leer
# LabelSchema: 72
# LabelSchemaDetail: 73
# LastAccessList: ERROR
# LeanPerformanceAnalysis: 74
# LicenseInfo: leer
# LineAssignment: leer
# LineAssignmentAggregate: leer
# LogChannel: leer
# Logbook: leer
# LoggingChangeManagement: leer
# LoggingConfiguration: 75
# LoggingKeyConfiguration: 76
# MDCostCenterAuthorization: 77
# MDDaysOff: 78
# MDFormula: 79
# MDFunctionAuthorization: 80
# MDFunctionProfiles: 81
# MDGroupPool: 82
# MDISetting: leer
# MDMFDayModel: 83
# MDMFShiftModel: 84
# MDMFYearModel: 85
# MDMachineCounter: 86
# MDNumberRanges: 87
# MDOperatorPosition: leer
# MDOrderGeneration: 88
# MDOrderGroup: leer
# MDOrderNetwork: 89
# MDOrderStatus: 90
# MDOrderStatusText: 91
# MDOrderType: 92
# MDPasswordExclusion: leer
# MDPerformanceAccount: 93
# MDPlanableMachines: 94
# MDPlanableOperations: ERROR
# MDPlanningProfile: leer
# MDPlanningProfileAssignment: leer
# MDPremiumIndicator: leer
# MDProcessingCode: 95
# MDReason: 96
# MDReasonText: 97
# MDResourceAllocation: leer
# MDResourceFamily: 98
# MDResourceGroup: 99
# MDResourceGroupAssignment: 100
# MDResourceType: 101
# MDResponsibilityArea: 102
# MDResponsibilityAreaAuthorization: 103
# MDResponsibilityProfiles: leer
# MDStatusClasses: 104
# MDStatusText: 105
# MDUnitConversion: 106
# MDUnits: 107
# MDUser: 108
# MDUserAccountRules: 109
# MDUserfieldConfiguration: 110
# MDUserfieldDefinition: 111
# MDUserfieldElements: 112
# MDUserfieldKey: 113
# MDWorkplaceTerminalAssignment: 114
# MDWorkplanComponents: leer
# MDWorkplanNotes: ERROR
# MDWorkplanOperation: 115
# MDWorkplanOrder: 116
# MDWorkplanOrderSequence: leer
# MDWorkplanProductionResources: leer
# MLEBasicConfiguration: 117
# MLECommunicationStatusMonitor: 118
# MLEConversionFunctions: 119
# MLEDataSegmentViewer: ERROR
# MLEDispatchModels: 120
# MLEFieldConfiguration: 121
# MLEFormulaCondition: 122
# MLEInboundTransactionData: leer
# MLEInboundTransactions: leer
# MLELogicalSystems: 123
# MLEOutboundTransactionData: 124
# MLEOutboundTransactions: leer
# MLESegmentConfiguration: 125
# MLETransactionProtocol: 126
# MachineStatusChangeQmAction: ERROR
# MasterDataCavities: leer
# MasterDataReqResources: leer
# MaterialBooking: ERROR
# MaterialBuffer: 127
# MaterialClass: 128
# MaterialToMaterialTypeAssignment: 129
# MaterialType: 130
# MaterialUsageRestrictions: leer
# MdeBdeEfficiency: 131
# MeasureAssignedComplaintAnalysis: 132
# MescTargetValues: ERROR
# MescWorkplaceResponsibility: ERROR
# MobileLayoutAssignment: leer
# MonthlyGroupPerformance: ERROR
# ObjectAttributes: 133
# OrderComponents: leer
# OrderProductionResources: leer
# OrderSerialNumber: leer
# OrderTypeCAQAssignment: 134
# OvertimePeriods: leer
# PaymentDayTypes: 135
# PaymentDependingOnShiftType: leer
# PaymentModels: 136
# PaymentRules: 137
# PdvAgProtokoll: 138
# PdvCharacteristicNumber: ERROR
# PdvCompressedSingleValue: ERROR
# PdvEvent: ERROR
# PdvOperation: 139
# PdvProcessParameter: ERROR
# PdvSampleValue: ERROR
# PdvSingleValue: ERROR
# PdvTagBasedSingleValue: ERROR
# PdvTagBasedSingleValueByProcessParam: ERROR
# PdvTagType: leer
# PdvVisualizationProcessParameter: ERROR
# PermittedInputMaterials: leer
# PersonalAbsencePlanning: leer
# PersonalAccountBalances: 140
# PersonalAccountCompensationPeriod: ERROR
# PersonalAccountJournal: ERROR
# PersonalAccountLimits: leer
# PersonalAccountPlanning: ERROR
# PersonalAccountsBooking: 141
# PersonalAccountsConfiguration: 142
# PersonalAttendanceOverview: 143
# PersonalChangesLog: leer
# PersonalDayTypes: leer
# PersonalFieldsConfiguration: 144
# PersonalFunction: ERROR
# PersonalFunctionProfile: ERROR
# PersonalGroupParticipation: ERROR
# PersonalJubileeList: ERROR
# PersonalLeaveEntitlement: leer
# PersonalMessages: leer
# PersonalModels: leer
# PersonalPlanningData: ERROR
# PersonalRemainingLeave: ERROR
# PersonalShiftRhythmModels: 145
# PersonalShiftmodel: leer
# PersonalTerminalInfoConfiguration: ERROR
# PersonalTerminalInformation: 146
# PersonalTimeEvaluation: ERROR
# PersonalTimeEvaluationControl: 147
# PersonalTimeInterfaceToPayrollAccounting: leer
# PersonalTimeMessageList: leer
# PersonalTimeMessageListConfiguration: 148
# PersonalTimeMonthlyEvaluation: 149
# PersonalTimeMonthlyResults: ERROR
# PersonalTimeMonthlyWagetypes: leer
# PersonalTimePlan: ERROR
# PersonalTimePublicHolidays: 150
# PersonalTimeResetResults: ERROR
# PersonalTimeSheet: ERROR
# PersonalTimeSheetColumns: leer
# PersonalTimeSheetConfiguration: 151
# PersonalTimeStatistic: ERROR
# PersonalWorkingTime: leer
# PersonalWorkingTimeDayTypes: 152
# PersonalWorkingTimeModels: 153
# PersonalYearOverview: ERROR
# PersonnelFile: leer
# PersonnelQualificationsAssignment: leer
# PersonnelRequirementOfWorkplaces: leer
# PersonnelWorkplaceAssignment: leer
# PlanningKeyfigure: leer
# PlanningKeyfigureAssignment: leer
# PlanningPriorityRules: 154
# PlanningPriorityRulesSorting: 155
# PlanningPriorityRulesTarget: leer
# PlanningSetupChangeMatrix: 156
# PlanningSimulationKeyFigures: leer
# PlanningSimulations: leer
# PlanningVariants: leer
# PlanningVariantsCapacity: leer
# PlanningVariantsConfiguration: leer
# PremiumGroups: leer
# ProcessCharacteristicAttribute: leer
# ProcessEvent: leer
# ProductionLevel: leer
# ProductionLevelAssignment: leer
# ProductionLevelTermAssignment: leer
# ProductionVariants: leer
# QMAnalysisSet: ERROR
# QMArea: 157
# QMAreaProcessData: 158
# QMCharacteristic: 159
# QMControlChart: ERROR
# QMDefectAssigned: 160
# QMDefectAssignedInspectionRequirement: 161
# QMDefectType: ERROR
# QMDepartments: 162
# QMDistributor: 163
# QMDistributorEntries: 164
# QMExternalPersons: 165
# QMFit: 166
# QMMeasure: 167
# QMMeasureAssigned: 168
# QMMeasureAssignedInspectionRequirement: 169
# QMMeasureGroup: 170
# QMNorm: 171
# QMOptions: 172
# QMPartyInCharge: 173
# QMReferenceIdentification: 174
# QMReleases: 175
# QMSample: 176
# QMSingleValue: 177
# QMSlowUserfields: ERROR
# QMSmaCharacteristic: ERROR
# QMSpecificationList: 178
# QMStatus: 179
# QMStatusType: 180
# QmsCatalogs: 181
# Qualifications: leer
# RPStatusAnalysis: ERROR
# RecordList: leer
# ReductionStrategy: 182
# ReportBatchJob: ERROR
# ResourceAttribute: leer
# ResourceAttributes: leer
# ResourceAttributesSelection: leer
# ResourceBookingRules: leer
# ResourceConsumptionByOrder: ERROR
# ResourceConsumptionByStatus: ERROR
# ResourceList: 183
# ResourceMeasure: leer
# ResourceParallelStatusAssignment: leer
# ResourceStatusAssignment: 184
# ResourceStatusDepOnOrderType: leer
# ResourceStatusText: leer
# ResourceStatusType: 185
# Resourcebooking: leer
# RessourceMdiAssignment: leer
# RoomZones: leer
# RoomZonesOverview: leer
# SYSAuthorization: 186
# SYSFeatureSets: 187
# SYSLanguages: 188
# SYSLicense: 189
# SYSLockedDataRecords: leer
# SYSPath: 190
# SYSReferenceData: 191
# SYSScheduler: 192
# SYSSelectionProfiles: leer
# SYSSetup: leer
# SYSShopFloorPlanningSetup: 193
# SamplingPlan: 194
# SapActivityType: leer
# SapPdcConfiguration: 195
# SapPpConfiguration: 196
# ServiceDictionary: 197
# Setup: 198
# SignatureMatrix: ERROR
# SignatureTypes: leer
# Softwarestatus: 199
# SupplyRelationship: leer
# SysLockBatch: ERROR
# SystemMeasurement: 200
# SystemProtocol: 201
# TargetValuesChanged: leer
# TeamMembersGlobal: ERROR
# TemplateOperation: 202
# TemplateOrder: leer
# TemplateOrderManagement: leer
# Terminal: 203
# TerminalGroups: 204
# TimeTickets: ERROR
# TracingMeasures: 205
# TransitionalDefinition: 206
# TransitionalDefinitionEntry: 207
# TransportMatrix: leer
# TransportUnit: 208
# TransportUnitToMaterialTypeAssignment: 209
# VariableWorkplace: leer
# WageTypeBookings: leer
# WageTypeDetermination: 210
# WageTypeGroups: leer
# WageTypeInteractions: leer
# WageTypeStatisticsConfiguration: leer
# WageTypes: 211
# WageTypesStatistics: leer
# WorkEquipment: leer
# WorkflowManagementFunction: ERROR
# WorkflowManagementGroup: ERROR
# WorkflowManagementRole: ERROR
# WorkingTimeDependingBreaks: leer
# WorkingTimeInformation: ERROR
# WorkplaceSchedule: leer
# WorkplaceStatusAssignment: 212
# Workplacebooking: 213
# WorkplanOrderComponents: leer
# WorkplanOrderManagement: leer
# WorkplanOrderProductionResources: leer
# Fertig!
