# %%
import requests
import json
import pandas as pd
import numpy as np

# %%
url_meta = "http://10.50.12.131:8080/meta/"
headers_meta = {
  'Authorization': 'Basic UmVzdHVzZXI6S2VubndvcnQwNA==',
  'Cookie': 'JSESSIONID=AAC2EFBE19BC028C7CE932443375F13B'
}
response_meta = requests.request("GET", url_meta, headers=headers_meta)
response_json_meta = json.loads(response_meta.text)

# %%
import json
with open('allClassesAndMethods.json', 'w') as outfile:
    json.dump(response_json_meta, outfile)

# %%
# count class.method
print("Anzahl Einträge in Response: {0}".format(len(response_json_meta)))
# Out:
# Anzahl Einträge in Response: 2656

# %%
# count classes
classes = []
for entry in response_json_meta:
    split = entry.split('.')
    classes.append(split[0])
# remove duplicates:
classes = list(dict.fromkeys(classes))
print("Anzahl verschiedener Klassen: {0}".format(len(classes)))

import json
with open('allClasses.json', 'w') as outfile:
    json.dump(classes, outfile)
# Out:
# Anzahl verschiedener Klassen: 526

# %%
# count methods
methods = []
for entry in response_json_meta:
    split = entry.split('.')
    methods.append(split[1])
# remove duplicates:
methods = list(dict.fromkeys(methods))
methods.sort()
print("Anzahl verschiedener Methoden: {0}".format(len(methods)))

import json
with open('allMethods.json', 'w') as outfile:
    json.dump(methods, outfile)
# Out:
# Anzahl verschiedener Methoden: 422

# %%
# count frequency of methods
methods = []
for entry in response_json_meta:
    split = entry.split('.')
    methods.append(split[1])
    
from collections import Counter
d = Counter(methods)

methodslist, frequencies = d.keys(), d.values()

pairs = list(zip(frequencies, methodslist))
pairs.sort(key=lambda tup: tup[0], reverse=True)
pairs

import json
with open('methodsWithCounter.json', 'w') as outfile:
    json.dump(pairs, outfile)
# Out:
# [(462, 'list'),
#  (310, 'update'),
#  (303, 'delete'),
#  (303, 'lock'),
#  (303, 'unlock'),
#  (302, 'insert'),
#  (78, 'copy'),
#  (52, 'new'),
#  (13, 'activate'),
#  (12, 'deactivate'),
#  (9, 'release'),
#  (8, 'deleteDocument'),
#  (8, 'insertDocument'),
#  (8, 'listDocument'),
#  (8, 'lockDocument'),
#  (8, 'unlockDocument'),
#  (8, 'updateDocument'),
#  (6, 'sign'),
#  (5, 'overview'),
#  (4, 'reject'),
#  (4, 'complete'),
#  (3, 'export'),
#  (3, 'inprocess'),
#  (3, 'listCurrentlyLoggedOn'),
#  (3, 'copyComplete'),
#  (3, 'copyMissingEntries'),
#  (2, 'execute'),
#  (2, 'listByWorkplace'),
#  (2, 'evaluate'),
#  (2, 'generate'),
#  (2, 'deleteNotes'),
#  (2, 'insertNotes'),
#  (2, 'listNotes'),
#  (2, 'lockNotes'),
#  (2, 'setstatus'),
#  (2, 'unlockNotes'),
#  (2, 'updateNotes'),
#  (2, 'refresh'),
#  (2, 'login'),
#  (2, 'modify'),
#  (2, 'setMachineStatus'),
#  (2, 'info'),
#  (2, 'authorize'),
#  (2, 'persist'),
#  (2, 'cancel'),
#  (2, 'listShopFloorPlanning'),
#  (2, 'statusreset'),
#  (2, 'progress'),
#  (2, 'specification'),
#  (2, 'listWithAdditionalInfo'),
#  (2, 'listAll'),
#  (2, 'copyMissing'),
#  (2, 'shiftlog'),
#  (2, 'internalResourceConsumptionData'),
#  (2, 'copySingleEntry'),
#  (2, 'compress'),
#  (2, 'listCompressed'),
#  (1, 'check'),
#  (1, 'listByTagDecimalBased'),
#  (1, 'listByTagWithSpecification'),
#  (1, 'listByWorkplaceDecimalBased'),
#  (1, 'listByWorkplaceWithSpecification'),
#  (1, 'listByWorkplaceTimeBased'),
#  (1, 'listByOperation'),
#  (1, 'listByOrder'),
#  (1, 'listByWorkplaceShift'),
#  (1, 'deleteEntry'),
#  (1, 'insertEntry'),
#  (1, 'listEntry'),
#  (1, 'lockEntry'),
#  (1, 'unlockEntry'),
#  (1, 'updateEntry'),
#  (1, 'listLastValuesByWorkplace'),
#  (1, 'listReferenceCurve'),
#  (1, 'import'),
#  (1, 'internalPersonalAuthorization'),
#  (1, 'internalProfileOnly1'),
#  (1, 'internalProfileOnly2'),
#  (1, 'internalProfileOnly3'),
#  (1, 'internalProfilesResolved1'),
#  (1, 'internalProfilesResolved2'),
#  (1, 'internalProfilesResolved3'),
#  (1, 'aipBatchInfo'),
#  (1, 'batchHistory'),
#  (1, 'batchSerialNumberHistory'),
#  (1, 'batchTracing'),
#  (1, 'createBatch'),
#  (1, 'createBatchHistory'),
#  (1, 'createBatchId'),
#  (1, 'expiryPreview'),
#  (1, 'expiryStatistics'),
#  (1, 'internal1CreateBatch'),
#  (1, 'internal1CreateBatchHistory'),
#  (1, 'listCurrentlyLoggedOnInput'),
#  (1, 'listCurrentlyLoggedOnOutput'),
#  (1, 'lockBatch'),
#  (1, 'pool'),
#  (1, 'repost'),
#  (1, 'setStatus'),
#  (1, 'split'),
#  (1, 'splitCollectiveBatch'),
#  (1, 'stockMonitoring'),
#  (1, 'stockOverview'),
#  (1, 'stockOverviewTPU'),
#  (1, 'usageDecision'),
#  (1, 'warningReport'),
#  (1, 'collectiveOperationAdd'),
#  (1, 'collectiveOperationCreate'),
#  (1, 'collectiveOperationDissolve'),
#  (1, 'collectiveOperationRemove'),
#  (1, 'enhancedSplitCreate'),
#  (1, 'enhancedSplitDissolve'),
#  (1, 'finishWeb'),
#  (1, 'interruptWeb'),
#  (1, 'listWeb'),
#  (1, 'lockOperation'),
#  (1, 'materialRequirementList'),
#  (1, 'overviewParallelLogon'),
#  (1, 'reactivate'),
#  (1, 'setstatusResource'),
#  (1, 'setstatusSecondary'),
#  (1, 'setupChangeList'),
#  (1, 'splitCreate'),
#  (1, 'splitDissolve'),
#  (1, 'tranOverview'),
#  (1, 'unlockOperation'),
#  (1, 'updateTargetQuantityForSubsequentOps'),
#  (1, 'schedule'),
#  (1, 'absoluteValuePlausibility'),
#  (1, 'capture'),
#  (1, 'captureAbsoluteValue'),
#  (1, 'monitoring'),
#  (1, 'reset'),
#  (1, 'requirementsOverview'),
#  (1, 'messages'),
#  (1, 'updatePinCode'),
#  (1, 'energyOverview'),
#  (1, 'enterMeasure'),
#  (1, 'listCurrentlyStatus'),
#  (1, 'resetResourceAccounts'),
#  (1, 'resourceDelete'),
#  (1, 'resourceInsert'),
#  (1, 'resourceList'),
#  (1, 'resourceLock'),
#  (1, 'resourceUnlock'),
#  (1, 'resourceUpdate'),
#  (1, 'setResourceStatus'),
#  (1, 'stockTransferPosting'),
#  (1, 'workplaceCopy'),
#  (1, 'workplaceDelete'),
#  (1, 'workplaceInsert'),
#  (1, 'workplaceList'),
#  (1, 'workplaceLock'),
#  (1, 'workplaceOverview'),
#  (1, 'workplaceUnlock'),
#  (1, 'workplaceUpdate'),
#  (1, 'lockcopy'),
#  (1, 'reservedBatchList'),
#  (1, 'newID'),
#  (1, 'newIdX'),
#  (1, 'check_dissolvable'),
#  (1, 'dissolve'),
#  (1, 'listTerminal'),
#  (1, 'adjustSump'),
#  (1, 'cancelReservation'),
#  (1, 'compositionRecipe'),
#  (1, 'compositionReport'),
#  (1, 'copyRecipe'),
#  (1, 'generateChargingOrder'),
#  (1, 'insertMaterial'),
#  (1, 'listChargingOrder'),
#  (1, 'listCompositionRestrictions'),
#  (1, 'listElements'),
#  (1, 'listMaterialStock'),
#  (1, 'listSelectedComponents'),
#  (1, 'makeReservation'),
#  (1, 'reuse'),
#  (1, 'startComposition'),
#  (1, 'updateMaterial'),
#  (1, 'listPrint'),
#  (1, 'deleteMulti'),
#  (1, 'deleteWeb'),
#  (1, 'createByImport'),
#  (1, 'setValidVersion'),
#  (1, 'backup'),
#  (1, 'fetchTestData'),
#  (1, 'activateSimpleDialog'),
#  (1, 'firstPassYieldAnalysis'),
#  (1, 'getFile'),
#  (1, 'getTextFile'),
#  (1, 'listVariableConsumption'),
#  (1, 'close'),
#  (1, 'existForUser'),
#  (1, 'existsHmsForTerminal'),
#  (1, 'forward'),
#  (1, 'insertHms'),
#  (1, 'listCommunicationPartners'),
#  (1, 'listHms'),
#  (1, 'listOpenHmsHead'),
#  (1, 'read'),
#  (1, 'autoclassify'),
#  (1, 'checkScenario'),
#  (1, 'discard'),
#  (1, 'recalculate'),
#  (1, 'recordCount'),
#  (1, 'causeDetectionMeasures'),
#  (1, 'causeMeasureLevels'),
#  (1, 'causePreventiveMeasures'),
#  (1, 'causes'),
#  (1, 'characteristics'),
#  (1, 'effects'),
#  (1, 'elementForId'),
#  (1, 'failures'),
#  (1, 'functions'),
#  (1, 'internalList'),
#  (1, 'copyNet'),
#  (1, 'copyFmeaTree'),
#  (1, 'copyNode'),
#  (1, 'copyStructure'),
#  (1, 'updateMeasureStatus'),
#  (1, 'updateRPN'),
#  (1, 'updateStructure'),
#  (1, 'deleteByPath'),
#  (1, 'downloadByPath'),
#  (1, 'downloadByPathMultiple'),
#  (1, 'downloadImageByPath'),
#  (1, 'downloadImageByPathMultiple'),
#  (1, 'listByPath'),
#  (1, 'uploadByPath'),
#  (1, 'restoreReference'),
#  (1, 'completeqms'),
#  (1, 'listDefectAssigned'),
#  (1, 'insertAndNotifyBCOMM'),
#  (1, 'stock'),
#  (1, 'listWorkplaceCurrentShift'),
#  (1, 'writeWorkplaceCurrentShift'),
#  (1, 'executeScript'),
#  (1, 'generateFile'),
#  (1, 'deleteDetail'),
#  (1, 'insertDetail'),
#  (1, 'listDetail'),
#  (1, 'updateDetail'),
#  (1, 'compare'),
#  (1, 'compare2'),
#  (1, 'restore'),
#  (1, 'undo'),
#  (1, 'view'),
#  (1, 'view2'),
#  (1, 'listCapturedValues'),
#  (1, 'createnr'),
#  (1, 'createOrder'),
#  (1, 'listLastOperationLogOff'),
#  (1, 'lockGroups'),
#  (1, 'unlockGroups'),
#  (1, 'listShopFloor'),
#  (1, 'listShopFloorResource'),
#  (1, 'listShopFloorWorkplace'),
#  (1, 'downloadSaveFiles'),
#  (1, 'save'),
#  (1, 'listByResource'),
#  (1, 'generateOrder'),
#  (1, 'escalateCycleNegActionLimitExceeded'),
#  (1, 'escalateCycleNegToleranceLimitExceeded'),
#  (1, 'escalateCyclePosActionLimitExceeded'),
#  (1, 'escalateCyclePosToleranceLimitExceeded'),
#  (1, 'escalateOperationRegister'),
#  (1, 'escalateOperationStart'),
#  (1, 'escalateOperationStatusChange'),
#  (1, 'escalateWorkplaceStatusMalfunction'),
#  (1, 'insertInbound'),
#  (1, 'insertOutbound'),
#  (1, 'updateInbound'),
#  (1, 'updateOutbound'),
#  (1, 'movedown'),
#  (1, 'moveup'),
#  (1, 'configureInboundFile'),
#  (1, 'configureInboundRfc'),
#  (1, 'configureOutboundFile'),
#  (1, 'configureOutboundPdm'),
#  (1, 'configureOutboundRfc'),
#  (1, 'configureOutboundUser'),
#  (1, 'connectionTest'),
#  (1, 'escalateBatchIsConsumed'),
#  (1, 'send'),
#  (1, 'listA'),
#  (1, 'listBde'),
#  (1, 'listBdeOnline'),
#  (1, 'listMde'),
#  (1, 'listMdeOnline'),
#  (1, 'listUE'),
#  (1, 'loadBdeBookings'),
#  (1, 'loadMdeBookings'),
#  (1, 'loadOperationScrap'),
#  (1, 'createNewVersion'),
#  (1, 'processRfidData'),
#  (1, 'scheduleControlling'),
#  (1, 'listByTagType'),
#  (1, 'listTimeRanges'),
#  (1, 'listPreviousIllnesses'),
#  (1, 'deleteDirect'),
#  (1, 'modifyDirect'),
#  (1, 'deleteBatch'),
#  (1, 'insertBatch'),
#  (1, 'durationReport'),
#  (1, 'listLastEvent'),
#  (1, 'timeLine'),
#  (1, 'calculateStatistic'),
#  (1, 'updateStatistic'),
#  (1, 'getValuesForOptionNumber'),
#  (1, 'efficiencyFailureReport'),
#  (1, 'timeProfile'),
#  (1, 'timeProfileCount'),
#  (1, 'costControl'),
#  (1, 'internal1'),
#  (1, 'internal2'),
#  (1, 'quantityControl'),
#  (1, 'quantityStatistics'),
#  (1, 'profile'),
#  (1, 'statistics'),
#  (1, 'personnelReport'),
#  (1, 'efficiencyProfile'),
#  (1, 'efficiencyReport'),
#  (1, 'efficiencyReportWorkplaceCurrentShift'),
#  (1, 'energyEfficiencyReport'),
#  (1, 'energyEfficiencyReportMachinery'),
#  (1, 'inspectionRejection'),
#  (1, 'lineEfficiencyProfile'),
#  (1, 'lineEfficiencyProfileByOrderOrBatch'),
#  (1, 'lineEfficiencyReport'),
#  (1, 'lineEfficiencyReportByOrderOrBatchOrArticle'),
#  (1, 'meantimeReport'),
#  (1, 'orderBookingsGroupedByOrderAndBatch'),
#  (1, 'rpaProfile'),
#  (1, 'rpaReport'),
#  (1, 'standstillReport'),
#  (1, 'statusAnalysisByClassification'),
#  (1, 'statusProfile'),
#  (1, 'statusReport'),
#  (1, 'statusclassProfile'),
#  (1, 'statusclassReport'),
#  (1, 'testBottleReport'),
#  (1, 'cycleProgression'),
#  (1, 'historyAdeA'),
#  (1, 'historyAdePCurrent'),
#  (1, 'historyAdePProtocol'),
#  (1, 'historyBdeComments'),
#  (1, 'historyEventMde'),
#  (1, 'historyEventResEinAus'),
#  (1, 'historyEventResStd'),
#  (1, 'historyMdeCurrent'),
#  (1, 'historyMdeProtocol'),
#  (1, 'historyNotes'),
#  (1, 'modifyWorkplaceHistoryComment'),
#  (1, 'resourceHistory'),
#  (1, 'standstillHitList'),
#  (1, 'updateResourceHistoryMeasureFinished'),
#  (1, 'workplaceHistory'),
#  (1, 'sendMail'),
#  (1, 'billing'),
#  (1, 'compressEmgData'),
#  (1, 'overviewComp'),
#  (1, 'internalOrderData'),
#  (1, 'internalWorkplaceData'),
#  (1, 'copyCompleteAllFamilies'),
#  (1, 'insertFile'),
#  (1, 'usedLicenseList'),
#  (1, 'usedLicenseListV2'),
#  (1, 'acquire'),
#  (1, 'managedIds'),
#  (1, 'principallyAvailable'),
#  (1, 'logout'),
#  (1, 'module'),
#  (1, 'program'),
#  (1, 'step'),
#  (1, 'acquisition'),
#  (1, 'combine'),
#  (1, 'listAssignedBatches'),
#  (1, 'listBatch'),
#  (1, 'listChildrenOfCollectiveBatch'),
#  (1, 'listChildrenOfLoggedOnCollectiveInputBatch'),
#  (1, 'listChildrenOfLoggedOnLeadingCollectiveInputBatch'),
#  (1, 'listLoggedOnCollectiveOutputBatch'),
#  (1, 'listValidChildrenOfCollectiveBatch'),
#  (1, 'recordData'),
#  (1, 'setMaterialConsumption'),
#  (1, 'setMaterialConsumptionMulti'),
#  (1, 'setOperationStatus'),
#  (1, 'setSerialNumberData'),
#  (1, 'updateProgressReport'),
#  (1, 'listForArticle'),
#  (1, 'listRaw'),
#  (1, 'listLogonPeriodRaw'),
#  (1, 'listOperationOrderShiftdateCompressed'),
#  (1, 'listSerialNumberTestResult'),
#  (1, 'buildExpression'),
#  (1, 'parseExpression'),
#  (1, 'hydraInstall'),
#  (1, 'listCurrentSessions'),
#  (1, 'requestCancel'),
#  (1, 'sessionToHydraUserMapper'),
#  (1, 'licenseCount'),
#  (1, 'listDialogUsage'),
#  (1, 'administrate'),
#  (1, 'updateStatus'),
#  (1, 'assemble'),
#  (1, 'desassemble'),
#  (1, 'create'),
#  (1, 'forwardTask'),
#  (1, 'getInfoData'),
#  (1, 'getTaskDetails'),
#  (1, 'listOutbound'),
#  (1, 'listTasks'),
#  (1, 'processTask'),
#  (1, 'resend'),
#  (1, 'setVariables'),
#  (1, 'startWorkflow'),
#  (1, 'syncUsers'),
#  (1, 'unlockTask'),
#  (1, 'workflowHistory'),
#  (1, 'workflowOverview'),
#  (1, 'workflowStatus'),
#  (1, 'listAllPossible')]

# %%
# count classes with 'list' or 'list...'
classesAndMethodsWithList = []
for entry in response_json_meta:
    split = entry.split('.')
    if(split[1][ 0 : 4 ] == 'list'):
        classesAndMethodsWithList.append(split)
print("Anzahl Kombination Klasse und list/list...-Methoden: {0}".format(len(classesAndMethodsWithList)))
classesAndMethodsWithList

import json
with open('classesAndMethodsWithList.json', 'w') as outfile:
    json.dump(classesAndMethodsWithList, outfile)
# Out:
# Anzahl Kombination Klasse und list/list...-Methoden: 548
# [['ATPInspectionGroup', 'list'],
#  ['ATPInspectionGroupAssignment', 'list'],
#  ['ATPWithdrawalBuffer', 'list'],
#  ['AbsenceReasons', 'list'],
#  ['AbsenceSettings', 'list'],
#  ['AbsenceToOrderBooking', 'list'],
#  ['AccessAlarmSuppression', 'list'],
#  ['AccessAlarmsAndDisturbancesHistory', 'list'],
#  ['AccessAuthorizations', 'list'],
#  ['AccessAuthorizationsHistory', 'list'],
#  ['AccessAuthorizationsList', 'list'],
#  ['AccessAuthorizationsTerminal', 'list'],
#  ['AccessGroups', 'list'],
#  ['AccessLog', 'list'],
#  ['AccessOpeningHours', 'list'],
#  ['AccessPoints', 'list'],
#  ['AccessProfileAssignment', 'list'],
#  ['AccessProfiles', 'list'],
#  ['AccessPublicHolidays', 'list'],
#  ['AccessStatus', 'list'],
#  ['AccessTimeModels', 'list'],
#  ['AccessTimeSpans', 'list'],
#  ['AccountingPeriods', 'list'],
#  ['AccountingPeriodsSelection', 'list'],
#  ['ActivityCodes', 'list'],
#  ['AnalysisAssignedComplaintAnalysis', 'list'],
#  ['AnalysisProcessData', 'listByTagDecimalBased'],
#  ['AnalysisProcessData', 'listByTagWithSpecification'],
#  ['AnalysisProcessData', 'listByWorkplaceDecimalBased'],
#  ['AnalysisProcessData', 'listByWorkplaceWithSpecification'],
#  ['AnalysisProcessDataHistogram', 'listByWorkplace'],
#  ['AnalysisProcessDataSpecification', 'listByWorkplaceTimeBased'],
#  ['AnalysisProcessDataStatistics', 'listByOperation'],
#  ['AnalysisProcessDataStatistics', 'listByOrder'],
#  ['AnalysisProcessDataStatistics', 'listByWorkplace'],
#  ['AnalysisProcessDataStatistics', 'listByWorkplaceShift'],
#  ['AnalysisProcessParameter', 'list'],
#  ['AnalysisSelection', 'list'],
#  ['AnalysisSelection', 'listEntry'],
#  ['AnalysisTag', 'list'],
#  ['AnalysisTagValues', 'listLastValuesByWorkplace'],
#  ['AnalysisWorkplace', 'list'],
#  ['AnalysisWorkplaceProcessParameter', 'listReferenceCurve'],
#  ['AnalysisWorkplaceStatus', 'list'],
#  ['ArchiveDataManagement', 'list'],
#  ['ArchiveDataManagementObject', 'list'],
#  ['ArchiveReloadManager', 'list'],
#  ['Article', 'list'],
#  ['ArticleGroup', 'list'],
#  ['Assessment', 'list'],
#  ['AssessmentCatalog', 'list'],
#  ['AssessmentClass', 'list'],
#  ['AssessmentClassification', 'list'],
#  ['AssessmentCriterion', 'list'],
#  ['AssessmentSubject', 'list'],
#  ['AssignmentOfPremiumAreas', 'list'],
#  ['AssignmentOfPremiumGroups', 'list'],
#  ['AttendanceBonus', 'list'],
#  ['AuthorizationCockpit', 'list'],
#  ['BOBatch', 'list'],
#  ['BOBatch', 'listCurrentlyLoggedOnInput'],
#  ['BOBatch', 'listCurrentlyLoggedOnOutput'],
#  ['BOOperation', 'list'],
#  ['BOOperation', 'listCurrentlyLoggedOn'],
#  ['BOOperation', 'listNotes'],
#  ['BOOperation', 'listWeb'],
#  ['BOOrder', 'list'],
#  ['BOOrder', 'listNotes'],
#  ['BOPComponents', 'list'],
#  ['BOPCycleParameters', 'list'],
#  ['BOPDocLinks', 'list'],
#  ['BOPMaintenance', 'list'],
#  ['BOPNotes', 'list'],
#  ['BOPOrderSequences', 'list'],
#  ['BOPProductionResources', 'list'],
#  ['BOPerson', 'list'],
#  ['BOPerson', 'listCurrentlyLoggedOn'],
#  ['BOResource', 'list'],
#  ['BOResource', 'listCurrentlyLoggedOn'],
#  ['BOResource', 'listCurrentlyStatus'],
#  ['BadgeLayout', 'list'],
#  ['Badges', 'list'],
#  ['BagCheck', 'list'],
#  ['BaselinePlan', 'list'],
#  ['BatchAttribute', 'list'],
#  ['BatchAttributeConfiguration', 'list'],
#  ['BatchLog', 'list'],
#  ['BatchRelation', 'list'],
#  ['BonusReasons', 'list'],
#  ['BradfordFactor', 'list'],
#  ['Category', 'list'],
#  ['ChangeOfPremiumGroups', 'list'],
#  ['CharacteristicAssignedComplaintAnalysis', 'list'],
#  ['CharacteristicStatistics', 'list'],
#  ['ClockingArchive', 'list'],
#  ['ClockingAuthorizations', 'list'],
#  ['ClockingAuthorizations', 'listTerminal'],
#  ['Clockings', 'list'],
#  ['Company', 'list'],
#  ['ComparisonClockingsBookings', 'list'],
#  ['Complaint', 'list'],
#  ['ComplaintAnalysis', 'list'],
#  ['ComplaintAssignment', 'list'],
#  ['ComplaintCostAnalysis', 'list'],
#  ['ComplaintCosts', 'list'],
#  ['ComplaintDetail', 'list'],
#  ['ComplaintDetail', 'listDocument'],
#  ['ComplaintHeader', 'listDocument'],
#  ['ComplaintMeasures', 'list'],
#  ['Composition', 'listChargingOrder'],
#  ['Composition', 'listCompositionRestrictions'],
#  ['Composition', 'listElements'],
#  ['Composition', 'listMaterialStock'],
#  ['Composition', 'listSelectedComponents'],
#  ['ControlChart', 'list'],
#  ['ControlPlan', 'list'],
#  ['ControlPlan', 'listDocument'],
#  ['ControlPlan', 'listPrint'],
#  ['CostCenters', 'list'],
#  ['CostType', 'list'],
#  ['CostTypeGroup', 'list'],
#  ['CounterResourceToMachineAssignment', 'list'],
#  ['CustomService', 'list'],
#  ['DCAdeLogRecord', 'list'],
#  ['DNCFamilyToMachineAssignment', 'list'],
#  ['DNCVersions', 'list'],
#  ['DailyPersonalPerformance', 'list'],
#  ['DialogButton', 'list'],
#  ['DialogConfiguration', 'list'],
#  ['DialogField', 'list'],
#  ['DialogSystemProtocol', 'list'],
#  ['DialogWorkflow', 'list'],
#  ['DocumentAssignedComplaintAnalysis', 'list'],
#  ['DocumentComplaint', 'list'],
#  ['DocumentInspection', 'list'],
#  ['DocumentLink', 'list'],
#  ['DocumentLinkType', 'list'],
#  ['DynamicHistoryBatchRelated', 'list'],
#  ['DynamicHistoryCharacteristicRelated', 'list'],
#  ['DynamicModificationAQL', 'list'],
#  ['DynamicModificationLevel', 'list'],
#  ['DynamicModificationMethod', 'list'],
#  ['DynamicModificationStandard', 'list'],
#  ['EnergyConsumptionForeCast', 'listVariableConsumption'],
#  ['EnergyRequirementsPlan', 'list'],
#  ['EnergyTargetActualComparison', 'list'],
#  ['EscalationEvaluation', 'list'],
#  ['EscalationEventConfiguration', 'list'],
#  ['EscalationEventRegistration', 'list'],
#  ['EscalationEventRegistrySolutions', 'list'],
#  ['EscalationEventRegistryVariables', 'list'],
#  ['EscalationFunctionGroups', 'list'],
#  ['EscalationMessages', 'list'],
#  ['EscalationMessages', 'listCommunicationPartners'],
#  ['EscalationMessages', 'listHms'],
#  ['EscalationMessages', 'listOpenHmsHead'],
#  ['EvaluationAssessmentCriterion', 'list'],
#  ['EvaluationAssessmentCriterionAnalysis', 'list'],
#  ['EvaluationsAssessmentManagement', 'list'],
#  ['EventMaintenance', 'list'],
#  ['Events', 'list'],
#  ['ExternalPerson', 'list'],
#  ['ExternalReport', 'list'],
#  ['FMEAEvaluationNumber', 'list'],
#  ['FMEAEvaluationNumberEntry', 'list'],
#  ['FMEAStructureNet', 'list'],
#  ['FMEAStructureTree', 'list'],
#  ['Failure', 'list'],
#  ['FailureGroup', 'list'],
#  ['FailureModeAnalysis', 'list'],
#  ['FailureModeAnalysisComplaint', 'list'],
#  ['FailureModeEffectsAnalysisOverview', 'list'],
#  ['File', 'listByPath'],
#  ['FormansChecklist', 'list'],
#  ['Gage', 'list'],
#  ['GraphicMachinery', 'list'],
#  ['GraphicMachineryObject', 'list'],
#  ['GroupBonusRecords', 'list'],
#  ['GroupPerformanceDevelopment', 'list'],
#  ['Histogram', 'list'],
#  ['IncentiveBonuses', 'list'],
#  ['IncentiveWageBasicSettings', 'list'],
#  ['IncentiveWageCalculation', 'list'],
#  ['IncentiveWageInterfaceToPayrollAccounting', 'list'],
#  ['IniConfiguration', 'list'],
#  ['IniDataConfiguration', 'list'],
#  ['InspectionCharacteristic', 'list'],
#  ['InspectionOrderCharacteristic', 'listDocument'],
#  ['InspectionPlan', 'list'],
#  ['InspectionPlan', 'listDocument'],
#  ['InspectionPlanCharacteristic', 'list'],
#  ['InspectionPlanCharacteristic', 'listDocument'],
#  ['InspectionPlanReference', 'list'],
#  ['InspectionPoint', 'list'],
#  ['InspectionRequirement', 'list'],
#  ['InspectionRequirement', 'listDocument'],
#  ['InspectionRequirementGlobal', 'listDefectAssigned'],
#  ['InspectionSample', 'list'],
#  ['InspectionSeverity', 'list'],
#  ['InspectionSeverityEntry', 'list'],
#  ['InspectionStations', 'list'],
#  ['InspectionStep', 'list'],
#  ['InterpolationPoint', 'list'],
#  ['InventoryLevelProjection', 'list'],
#  ['InventoryLimit', 'list'],
#  ['JobTrigger', 'list'],
#  ['Kanban', 'list'],
#  ['Keyfigure', 'listWorkplaceCurrentShift'],
#  ['LabelAssignment', 'list'],
#  ['LabelDesign', 'list'],
#  ['LabelReprint', 'list'],
#  ['LabelSchema', 'list'],
#  ['LabelSchemaDetail', 'list'],
#  ['LastAccessList', 'list'],
#  ['LeanPerformanceAnalysis', 'list'],
#  ['LicenseInfo', 'list'],
#  ['LineAssignment', 'list'],
#  ['LineAssignmentAggregate', 'list'],
#  ['LogChannel', 'list'],
#  ['Logbook', 'list'],
#  ['Logbook', 'listDetail'],
#  ['LoggingChangeManagement', 'list'],
#  ['LoggingConfiguration', 'list'],
#  ['LoggingKeyConfiguration', 'list'],
#  ['MDCostCenterAuthorization', 'list'],
#  ['MDDaysOff', 'list'],
#  ['MDFormula', 'list'],
#  ['MDFunctionAuthorization', 'list'],
#  ['MDFunctionProfiles', 'list'],
#  ['MDGroupPool', 'list'],
#  ['MDISetting', 'list'],
#  ['MDMFDayModel', 'list'],
#  ['MDMFShiftModel', 'list'],
#  ['MDMFYearModel', 'list'],
#  ['MDMachineCounter', 'list'],
#  ['MDMachineCounter', 'listCapturedValues'],
#  ['MDNumberRanges', 'list'],
#  ['MDOperatorPosition', 'list'],
#  ['MDOrderGeneration', 'list'],
#  ['MDOrderGroup', 'list'],
#  ['MDOrderNetwork', 'list'],
#  ['MDOrderNetwork', 'listShopFloorPlanning'],
#  ['MDOrderStatus', 'list'],
#  ['MDOrderStatusText', 'list'],
#  ['MDOrderType', 'list'],
#  ['MDPasswordExclusion', 'list'],
#  ['MDPerformanceAccount', 'list'],
#  ['MDPlanableMachines', 'list'],
#  ['MDPlanableMachines', 'listLastOperationLogOff'],
#  ['MDPlanableOperations', 'list'],
#  ['MDPlanningProfile', 'list'],
#  ['MDPlanningProfile', 'listShopFloorPlanning'],
#  ['MDPlanningProfileAssignment', 'list'],
#  ['MDPremiumIndicator', 'list'],
#  ['MDProcessingCode', 'list'],
#  ['MDReason', 'list'],
#  ['MDReasonText', 'list'],
#  ['MDResourceAllocation', 'list'],
#  ['MDResourceAllocation', 'listShopFloor'],
#  ['MDResourceAllocation', 'listShopFloorResource'],
#  ['MDResourceAllocation', 'listShopFloorWorkplace'],
#  ['MDResourceFamily', 'list'],
#  ['MDResourceGroup', 'list'],
#  ['MDResourceGroupAssignment', 'list'],
#  ['MDResourceType', 'list'],
#  ['MDResponsibilityArea', 'list'],
#  ['MDResponsibilityAreaAuthorization', 'list'],
#  ['MDResponsibilityProfiles', 'list'],
#  ['MDStatusClasses', 'list'],
#  ['MDStatusText', 'list'],
#  ['MDUnitConversion', 'list'],
#  ['MDUnits', 'list'],
#  ['MDUser', 'list'],
#  ['MDUserAccountRules', 'list'],
#  ['MDUserfieldConfiguration', 'list'],
#  ['MDUserfieldConfiguration', 'listByResource'],
#  ['MDUserfieldDefinition', 'list'],
#  ['MDUserfieldElements', 'list'],
#  ['MDUserfieldKey', 'list'],
#  ['MDWorkplaceTerminalAssignment', 'list'],
#  ['MDWorkplanComponents', 'list'],
#  ['MDWorkplanNotes', 'list'],
#  ['MDWorkplanOperation', 'list'],
#  ['MDWorkplanOrder', 'list'],
#  ['MDWorkplanOrderSequence', 'list'],
#  ['MDWorkplanProductionResources', 'list'],
#  ['MLEBasicConfiguration', 'list'],
#  ['MLECommunicationStatusMonitor', 'list'],
#  ['MLEConversionFunctions', 'list'],
#  ['MLEDataSegmentViewer', 'list'],
#  ['MLEDispatchModels', 'list'],
#  ['MLEFieldConfiguration', 'list'],
#  ['MLEFormulaCondition', 'list'],
#  ['MLEInboundTransactionData', 'list'],
#  ['MLEInboundTransactions', 'list'],
#  ['MLELogicalSystems', 'list'],
#  ['MLEOutboundTransactionData', 'list'],
#  ['MLEOutboundTransactions', 'list'],
#  ['MLESegmentConfiguration', 'list'],
#  ['MLETransactionProtocol', 'list'],
#  ['MachineStatusChangeQmAction', 'list'],
#  ['MasterDataCavities', 'list'],
#  ['MasterDataReqResources', 'list'],
#  ['MaterialBooking', 'list'],
#  ['MaterialBuffer', 'list'],
#  ['MaterialClass', 'list'],
#  ['MaterialToMaterialTypeAssignment', 'list'],
#  ['MaterialType', 'list'],
#  ['MaterialUsageRestrictions', 'list'],
#  ['MdeBdeEfficiency', 'list'],
#  ['MdeBdeEfficiency', 'listA'],
#  ['MdeBdeEfficiency', 'listBde'],
#  ['MdeBdeEfficiency', 'listBdeOnline'],
#  ['MdeBdeEfficiency', 'listMde'],
#  ['MdeBdeEfficiency', 'listMdeOnline'],
#  ['MdeBdeEfficiency', 'listUE'],
#  ['MeasureAssignedComplaintAnalysis', 'list'],
#  ['MescTargetValues', 'list'],
#  ['MescWorkplaceResponsibility', 'list'],
#  ['MobileLayoutAssignment', 'list'],
#  ['MonthlyGroupPerformance', 'list'],
#  ['ObjectAttributes', 'list'],
#  ['OrderComponents', 'list'],
#  ['OrderProductionResources', 'list'],
#  ['OrderSerialNumber', 'list'],
#  ['OrderTypeCAQAssignment', 'list'],
#  ['OvertimePeriods', 'list'],
#  ['PaymentDayTypes', 'list'],
#  ['PaymentDependingOnShiftType', 'list'],
#  ['PaymentModels', 'list'],
#  ['PaymentRules', 'list'],
#  ['PdvAgProtokoll', 'list'],
#  ['PdvCharacteristicNumber', 'list'],
#  ['PdvCompressedSingleValue', 'list'],
#  ['PdvEvent', 'list'],
#  ['PdvOperation', 'list'],
#  ['PdvProcessParameter', 'list'],
#  ['PdvSampleValue', 'list'],
#  ['PdvSingleValue', 'list'],
#  ['PdvSingleValue', 'listWithAdditionalInfo'],
#  ['PdvTagBasedSingleValue', 'list'],
#  ['PdvTagBasedSingleValue', 'listWithAdditionalInfo'],
#  ['PdvTagBasedSingleValueByProcessParam', 'list'],
#  ['PdvTagId', 'listByTagType'],
#  ['PdvTagId', 'listTimeRanges'],
#  ['PdvTagType', 'list'],
#  ['PdvVisualizationProcessParameter', 'list'],
#  ['PermittedInputMaterials', 'list'],
#  ['PersonalAbsencePlanning', 'list'],
#  ['PersonalAbsencePlanning', 'listPreviousIllnesses'],
#  ['PersonalAccountBalances', 'list'],
#  ['PersonalAccountBalances', 'listAll'],
#  ['PersonalAccountCompensationPeriod', 'list'],
#  ['PersonalAccountJournal', 'list'],
#  ['PersonalAccountLimits', 'list'],
#  ['PersonalAccountPlanning', 'list'],
#  ['PersonalAccountsBooking', 'list'],
#  ['PersonalAccountsConfiguration', 'list'],
#  ['PersonalAttendanceOverview', 'list'],
#  ['PersonalChangesLog', 'list'],
#  ['PersonalDayTypes', 'list'],
#  ['PersonalFieldsConfiguration', 'list'],
#  ['PersonalFunction', 'list'],
#  ['PersonalFunctionProfile', 'list'],
#  ['PersonalGroupParticipation', 'list'],
#  ['PersonalJubileeList', 'list'],
#  ['PersonalLeaveEntitlement', 'list'],
#  ['PersonalMessages', 'list'],
#  ['PersonalModels', 'list'],
#  ['PersonalPlanningData', 'list'],
#  ['PersonalRemainingLeave', 'list'],
#  ['PersonalShiftRhythmModels', 'list'],
#  ['PersonalShiftmodel', 'list'],
#  ['PersonalTerminalInfoConfiguration', 'list'],
#  ['PersonalTerminalInformation', 'list'],
#  ['PersonalTimeEvaluation', 'list'],
#  ['PersonalTimeEvaluationControl', 'list'],
#  ['PersonalTimeInterfaceToPayrollAccounting', 'list'],
#  ['PersonalTimeMessageList', 'list'],
#  ['PersonalTimeMessageListConfiguration', 'list'],
#  ['PersonalTimeMonthlyEvaluation', 'list'],
#  ['PersonalTimeMonthlyResults', 'list'],
#  ['PersonalTimeMonthlyWagetypes', 'list'],
#  ['PersonalTimePlan', 'list'],
#  ['PersonalTimePublicHolidays', 'list'],
#  ['PersonalTimeResetResults', 'list'],
#  ['PersonalTimeSheet', 'list'],
#  ['PersonalTimeSheetColumns', 'list'],
#  ['PersonalTimeSheetConfiguration', 'list'],
#  ['PersonalTimeStatistic', 'list'],
#  ['PersonalWorkingTime', 'list'],
#  ['PersonalWorkingTimeDayTypes', 'list'],
#  ['PersonalWorkingTimeModels', 'list'],
#  ['PersonalYearOverview', 'list'],
#  ['PersonnelFile', 'list'],
#  ['PersonnelQualificationsAssignment', 'list'],
#  ['PersonnelRequirementOfWorkplaces', 'list'],
#  ['PersonnelWorkplaceAssignment', 'list'],
#  ['PlanningKeyfigure', 'list'],
#  ['PlanningKeyfigureAssignment', 'list'],
#  ['PlanningPriorityRules', 'list'],
#  ['PlanningPriorityRulesSorting', 'list'],
#  ['PlanningPriorityRulesTarget', 'list'],
#  ['PlanningSetupChangeMatrix', 'list'],
#  ['PlanningSimulationKeyFigures', 'list'],
#  ['PlanningSimulations', 'list'],
#  ['PlanningVariants', 'list'],
#  ['PlanningVariantsCapacity', 'list'],
#  ['PlanningVariantsConfiguration', 'list'],
#  ['PremiumGroups', 'list'],
#  ['ProcessCharacteristicAttribute', 'list'],
#  ['ProcessEvent', 'list'],
#  ['ProcessEvent', 'listLastEvent'],
#  ['ProductionLevel', 'list'],
#  ['ProductionLevelAssignment', 'list'],
#  ['ProductionLevelTermAssignment', 'list'],
#  ['ProductionVariants', 'list'],
#  ['QMAnalysisSet', 'list'],
#  ['QMArea', 'list'],
#  ['QMAreaProcessData', 'list'],
#  ['QMCharacteristic', 'list'],
#  ['QMCharacteristic', 'listDocument'],
#  ['QMControlChart', 'list'],
#  ['QMDefectAssigned', 'list'],
#  ['QMDefectAssignedInspectionRequirement', 'list'],
#  ['QMDefectType', 'list'],
#  ['QMDepartments', 'list'],
#  ['QMDistributor', 'list'],
#  ['QMDistributorEntries', 'list'],
#  ['QMExternalPersons', 'list'],
#  ['QMFit', 'list'],
#  ['QMMeasure', 'list'],
#  ['QMMeasureAssigned', 'list'],
#  ['QMMeasureAssignedInspectionRequirement', 'list'],
#  ['QMMeasureGroup', 'list'],
#  ['QMNorm', 'list'],
#  ['QMOptions', 'list'],
#  ['QMPartyInCharge', 'list'],
#  ['QMReferenceIdentification', 'list'],
#  ['QMReleases', 'list'],
#  ['QMSample', 'list'],
#  ['QMSingleValue', 'list'],
#  ['QMSlowUserfields', 'list'],
#  ['QMSmaCharacteristic', 'list'],
#  ['QMSpecificationList', 'list'],
#  ['QMStatus', 'list'],
#  ['QMStatus', 'listAll'],
#  ['QMStatusType', 'list'],
#  ['QmsCatalogs', 'list'],
#  ['Qualifications', 'list'],
#  ['RPStatusAnalysis', 'list'],
#  ['RecordList', 'list'],
#  ['ReductionStrategy', 'list'],
#  ['ReportBatchJob', 'list'],
#  ['ResourceAttribute', 'list'],
#  ['ResourceAttributes', 'list'],
#  ['ResourceAttributesSelection', 'list'],
#  ['ResourceBookingRules', 'list'],
#  ['ResourceConsumptionByOrder', 'list'],
#  ['ResourceConsumptionByStatus', 'list'],
#  ['ResourceList', 'list'],
#  ['ResourceMeasure', 'list'],
#  ['ResourceParallelStatusAssignment', 'list'],
#  ['ResourceStatusAssignment', 'list'],
#  ['ResourceStatusDepOnOrderType', 'list'],
#  ['ResourceStatusText', 'list'],
#  ['ResourceStatusType', 'list'],
#  ['Resourcebooking', 'list'],
#  ['RessourceMdiAssignment', 'list'],
#  ['RoomZones', 'list'],
#  ['RoomZonesOverview', 'list'],
#  ['SYSAuthorization', 'list'],
#  ['SYSFeatureSets', 'list'],
#  ['SYSLanguages', 'list'],
#  ['SYSLicense', 'list'],
#  ['SYSLockedDataRecords', 'list'],
#  ['SYSPath', 'list'],
#  ['SYSReferenceData', 'list'],
#  ['SYSScheduler', 'list'],
#  ['SYSSelectionProfiles', 'list'],
#  ['SYSSetup', 'list'],
#  ['SYSShopFloorPlanningSetup', 'list'],
#  ['SamplingPlan', 'list'],
#  ['SapActivityType', 'list'],
#  ['SapPdcConfiguration', 'list'],
#  ['SapPpConfiguration', 'list'],
#  ['SerialNumber', 'listAssignedBatches'],
#  ['SerialNumber', 'listBatch'],
#  ['SerialNumber', 'listChildrenOfCollectiveBatch'],
#  ['SerialNumber', 'listChildrenOfLoggedOnCollectiveInputBatch'],
#  ['SerialNumber', 'listChildrenOfLoggedOnLeadingCollectiveInputBatch'],
#  ['SerialNumber', 'listLoggedOnCollectiveOutputBatch'],
#  ['SerialNumber', 'listValidChildrenOfCollectiveBatch'],
#  ['ServiceDictionary', 'list'],
#  ['Setup', 'list'],
#  ['SignatureMatrix', 'list'],
#  ['SignatureTypes', 'list'],
#  ['Softwarestatus', 'list'],
#  ['StatProcessDataFirstPassYieldOrder', 'listCompressed'],
#  ['StatProcessDataFirstPassYieldOrder', 'listForArticle'],
#  ['StatProcessDataFirstPassYieldOrder', 'listRaw'],
#  ['StatProcessDataOperationPeriod', 'listCompressed'],
#  ['StatProcessDataOperationPeriod', 'listLogonPeriodRaw'],
#  ['StatProcessDataOperationPeriod', 'listOperationOrderShiftdateCompressed'],
#  ['StatProcessDataOperationPeriod', 'listSerialNumberTestResult'],
#  ['SupplyRelationship', 'list'],
#  ['SysLockBatch', 'list'],
#  ['System', 'listCurrentSessions'],
#  ['SystemMeasurement', 'list'],
#  ['SystemMeasurement', 'listDialogUsage'],
#  ['SystemProtocol', 'list'],
#  ['TargetValuesChanged', 'list'],
#  ['TeamMembersGlobal', 'list'],
#  ['TemplateOperation', 'list'],
#  ['TemplateOrder', 'list'],
#  ['TemplateOrderManagement', 'list'],
#  ['Terminal', 'list'],
#  ['TerminalGroups', 'list'],
#  ['TimeTickets', 'list'],
#  ['TracingMeasures', 'list'],
#  ['TransitionalDefinition', 'list'],
#  ['TransitionalDefinitionEntry', 'list'],
#  ['TransportMatrix', 'list'],
#  ['TransportUnit', 'list'],
#  ['TransportUnitToMaterialTypeAssignment', 'list'],
#  ['VariableWorkplace', 'list'],
#  ['WageTypeBookings', 'list'],
#  ['WageTypeDetermination', 'list'],
#  ['WageTypeGroups', 'list'],
#  ['WageTypeInteractions', 'list'],
#  ['WageTypeStatisticsConfiguration', 'list'],
#  ['WageTypes', 'list'],
#  ['WageTypesStatistics', 'list'],
#  ['WorkEquipment', 'list'],
#  ['WorkflowManagement', 'listOutbound'],
#  ['WorkflowManagement', 'listTasks'],
#  ['WorkflowManagementFunction', 'list'],
#  ['WorkflowManagementFunction', 'listAllPossible'],
#  ['WorkflowManagementGroup', 'list'],
#  ['WorkflowManagementRole', 'list'],
#  ['WorkingTimeDependingBreaks', 'list'],
#  ['WorkingTimeInformation', 'list'],
#  ['WorkplaceSchedule', 'list'],
#  ['WorkplaceStatusAssignment', 'list'],
#  ['Workplacebooking', 'list'],
#  ['WorkplanOrderComponents', 'list'],
#  ['WorkplanOrderManagement', 'list'],
#  ['WorkplanOrderProductionResources', 'list']]
